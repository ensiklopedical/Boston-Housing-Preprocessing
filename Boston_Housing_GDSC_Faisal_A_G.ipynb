# %% [markdown]
# #BOSTON HOUSING
# #(FINISHED)
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# - CRIM - per capita crime rate by town
# - ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS - proportion of non-retail business acres per town.
# - CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# - NOX - nitric oxides concentration (parts per 10 million)
# - RM - average number of rooms per dwelling
# - AGE - proportion of owner-occupied units built prior to 1940
# - DIS - weighted distances to five Boston employment centres
# - RAD - index of accessibility to radial highways
# - TAX - full-value property-tax rate per USD10,000
# - PTRATIO - pupil-teacher ratio by town
# - B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT - % lower status of the population
# - MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# # IMPORT

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv('/boston_housing.csv')

# %% [markdown]
# #STATISTICAL ANALYSIS

# %% [markdown]
# ## Descriptive Information

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.keys()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %% [markdown]
# ## Descriptive Statistics

# %%
print("Dataset Shape = ", df.shape)
# Out:
# Dataset Shape =  (506, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
sns.histplot(data = df['crim'], kde = True)

# %%
sns.histplot(data = df['zn'], kde = True)

# %%
sns.histplot(data = df['indus'], kde = True)

# %%
sns.histplot(data = df['nox'], kde = True)

# %%
sns.histplot(data = df['rm'], kde = True)

# %%
sns.histplot(data = df['age'], kde = True)

# %%
sns.histplot(data = df['dis'], kde = True)

# %%
sns.histplot(data = df['rad'], kde = True)

# %%
sns.histplot(data = df['tax'], kde = True)

# %%
sns.histplot(data = df['ptratio'], kde = True)

# %%
sns.histplot(data = df['b'], kde = True)

# %%
sns.histplot(data = df['lstat'], kde = True)

# %%
sns.histplot(data = df['medv'], kde = True)

# %%
sns.histplot(data = df['chas'], kde = True)

#kolom ini engga tau kenapa error terus dipake apa juga error, engga paham
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'chas'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# # DATA PRE-PROCESSING

# %% [markdown]
# ## Drop Columns

# %% [markdown]
# tidak diperlukan karena tidak diketahui datanya dibersihkan untuk keperluan apa.

# %% [markdown]
# ## Missing Values

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# tidak ada missing values

# %% [markdown]
# ##Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# tidak ada baris yang terduplikasi

# %% [markdown]
# ##Outliers

# %%
crim = df.crim
crim_upper = crim.mean() + 3*crim.std()
print(crim_upper)
crim_outliers = df[(crim > crim_upper) | (crim < 0)]
crim_outliers
# Out:
# 24.514283284491352
#         crim   zn  indus    nox     rm    age     dis  rad  tax  ptratio  \
# 398  38.3518  0.0   18.1  0.693  5.453  100.0  1.4896   24  666     20.2
# 400  25.0461  0.0   18.1  0.693  5.987  100.0  1.5888   24  666     20.2
# 403  24.8017  0.0   18.1  0.693  5.349   96.0  1.7028   24  666     20.2
# 404  41.5292  0.0   18.1  0.693  5.531   85.4  1.6074   24  666     20.2
# 405  67.9208  0.0   18.1  0.693  5.683  100.0  1.4254   24  666     20.2
# 410  51.1358  0.0   18.1  0.597  5.757  100.0  1.4130   24  666     20.2
# 413  28.6558  0.0   18.1  0.597  5.155  100.0  1.5894   24  666     20.2
# 414  45.7461  0.0   18.1  0.693  4.519  100.0  1.6582   24  666     20.2
# 417  25.9406  0.0   18.1  0.679  5.304   89.1  1.6475   24  666     20.2
# 427  37.6619  0.0   18.1  0.679  6.202   78.7  1.8629   24  666     20.2
#
#           b  lstat  medv  chas_0  chas_1
# 398  396.90  30.59   5.0       1       0
# 400  396.90  26.77   5.6       1       0
# ...

# %%
df = df.drop(418, 380)

# %%
ZN = df.zn
zn_upper = ZN.mean() + 3*ZN.std()
print(zn_upper)
zn_outliers = df[(ZN > zn_upper) | (ZN < 0)]
zn_outliers
# Out:
# 81.33099534718177
#         crim     zn  indus  chas     nox     rm   age      dis  rad  tax  \
# 55   0.01311   90.0   1.22     0  0.4030  7.249  21.9   8.6966    5  226
# 56   0.02055   85.0   0.74     0  0.4100  6.383  35.7   9.1876    2  313
# 57   0.01432  100.0   1.32     0  0.4110  6.816  40.5   8.3248    5  256
# 199  0.03150   95.0   1.47     0  0.4030  6.975  15.3   7.6534    3  402
# 200  0.01778   95.0   1.47     0  0.4030  7.135  13.9   7.6534    3  402
# 201  0.03445   82.5   2.03     0  0.4150  6.162  38.4   6.2700    2  348
# 202  0.02177   82.5   2.03     0  0.4150  7.610  15.7   6.2700    2  348
# 203  0.03510   95.0   2.68     0  0.4161  7.853  33.2   5.1180    4  224
# 204  0.02009   95.0   2.68     0  0.4161  8.034  31.9   5.1180    4  224
# 256  0.01538   90.0   3.75     0  0.3940  7.454  34.2   6.3361    3  244
# 283  0.01501   90.0   1.21     1  0.4010  7.923  24.8   5.8850    1  198
# 284  0.00906   90.0   2.97     0  0.4000  7.088  20.8   7.3073    1  285
# ...

# %%
indus = df.indus
indus_upper = indus.mean() + 3*indus.std()
print(indus_upper)
indus_outliers = df[(indus > indus_upper) | (indus < 0)]
indus_outliers
# Out:
# 31.717837478819238
# Empty DataFrame
# Columns: [crim, zn, indus, chas, nox, rm, age, dis, rad, tax, ptratio, b, lstat, medv]
# Index: []

# %%
nox  = df.nox
nox_upper = nox.mean() + 3*nox.std()
print(nox_upper)
nox_outliers = df[(nox > nox_upper) | (nox < 0)]
nox_outliers
# Out:
# 0.9023280862912054
# Empty DataFrame
# Columns: [crim, zn, indus, chas, nox, rm, age, dis, rad, tax, ptratio, b, lstat, medv]
# Index: []

# %%
rm  = df.rm
rm_upper = rm.mean() + 3*rm.std()
print(rm_upper)
rm_outliers = df[(rm > rm_upper) | (rm < 0)]
rm_outliers
# Out:
# 8.392485817597748
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 225  0.52693   0.0   6.20     0  0.504  8.725  83.0  2.8944    8  307
# 257  0.61154  20.0   3.97     0  0.647  8.704  86.9  1.8010    5  264
# 262  0.52014  20.0   3.97     0  0.647  8.398  91.5  2.2885    5  264
# 364  3.47428   0.0  18.10     1  0.718  8.780  82.9  1.9047   24  666
#
#      ptratio       b  lstat  medv
# 225     17.4  382.00   4.63  50.0
# 257     13.0  389.70   5.12  50.0
# 262     13.0  386.86   5.91  48.8
# 364     20.2  354.55   5.29  21.9

# %%
age  = df.age
age_upper = age.mean() + 3*age.std()
print(age_upper)
age_outliers = df[(age > age_upper) | (age < 0)]
age_outliers
# Out:
# 153.0214854064816
# Empty DataFrame
# Columns: [crim, zn, indus, chas, nox, rm, age, dis, rad, tax, ptratio, b, lstat, medv]
# Index: []

# %%
dis  = df.dis
dis_upper = dis.mean() + 3*dis.std()
print(dis_upper)
dis_outliers = df[(dis > dis_upper) | (dis < 0)]
dis_outliers
# Out:
# 10.112173067629868
#         crim    zn  indus  chas    nox     rm   age      dis  rad  tax  \
# 351  0.07950  60.0   1.69     0  0.411  6.579  35.9  10.7103    4  411
# 352  0.07244  60.0   1.69     0  0.411  5.884  18.5  10.7103    4  411
# 353  0.01709  90.0   2.02     0  0.410  6.728  36.1  12.1265    5  187
# 354  0.04301  80.0   1.91     0  0.413  5.663  21.9  10.5857    4  334
# 355  0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4  334
#
#      ptratio       b  lstat  medv
# 351     18.3  370.78   5.49  24.1
# 352     18.3  392.33   7.79  18.6
# 353     17.0  384.46   4.50  30.1
# 354     22.0  382.80   8.05  18.2
# 355     22.0  376.04   5.57  20.6

# %%
rad  = df.rad
rad_upper = rad.mean() + 3*rad.std()
print(rad_upper)
rad_outliers = df[(rad > rad_upper) | (rad < 0)]
rad_outliers
# Out:
# 35.67118526734261
# Empty DataFrame
# Columns: [crim, zn, indus, chas, nox, rm, age, dis, rad, tax, ptratio, b, lstat, medv]
# Index: []

# %%
tax  = df.tax
tax_upper = tax.mean() + 3*tax.std()
print(rad_upper)
tax_outliers = df[(tax > tax_upper) | (tax < 0)]
tax_outliers
# Out:
# 35.67118526734261
# Empty DataFrame
# Columns: [crim, zn, indus, chas, nox, rm, age, dis, rad, tax, ptratio, b, lstat, medv]
# Index: []

# %%
ptr  = df.ptratio
ptr_upper = ptr.mean() + 3*ptr.std()
print(ptr_upper)
ptr_outliers = df[(ptr > ptr_upper) | (ptr < 0)]
ptr_outliers
# Out:
# 24.95037016798127
# Empty DataFrame
# Columns: [crim, zn, indus, chas, nox, rm, age, dis, rad, tax, ptratio, b, lstat, medv]
# Index: []

# %%
b  = df.b
b_upper = b.mean() + 3*b.std()
print(b_upper)
b_outliers = df[(b > b_upper) | (b < 0)]
b_outliers
# Out:
# 630.5586247730268
# Empty DataFrame
# Columns: [crim, zn, indus, chas, nox, rm, age, dis, rad, tax, ptratio, b, lstat, medv]
# Index: []

# %%
lstat  = df.lstat
lstat_upper = lstat.mean() + 3*lstat.std()
print(lstat_upper)
lstat_outliers = df[(lstat > lstat_upper) | (lstat < 0)]
lstat_outliers
# Out:
# 34.07624777515244
#          crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 141   1.62864  0.0  21.89     0  0.624  5.019  100.0  1.4394    4  437
# 373  11.10810  0.0  18.10     0  0.668  4.906  100.0  1.1742   24  666
# 374  18.49820  0.0  18.10     0  0.668  4.138  100.0  1.1370   24  666
# 412  18.81100  0.0  18.10     0  0.597  4.628  100.0  1.5539   24  666
# 414  45.74610  0.0  18.10     0  0.693  4.519  100.0  1.6582   24  666
#
#      ptratio       b  lstat  medv
# 141     21.2  396.90  34.41  14.4
# 373     20.2  396.90  34.77  13.8
# 374     20.2  396.90  37.97  13.8
# 412     20.2   28.79  34.37  17.9
# 414     20.2   88.27  36.98   7.0

# %%
medv  = df.medv
medv_upper = medv.mean() + 3*medv.std()
print(medv_upper)
medv_outliers = df[(medv > medv_upper) | (medv < 0)]
medv_outliers
# Out:
# 50.124118586250134
# Empty DataFrame
# Columns: [crim, zn, indus, chas, nox, rm, age, dis, rad, tax, ptratio, b, lstat, medv]
# Index: []

# %% [markdown]
# Pada tahap ini, yang dihapus hanyalah dua baris karena terlihat cukup jauh, yaitu pada baris yang memiliki nilai lebih tinggi dari batas atas cukup banyak pada kolom CRIM
#
# Kolom lainnya walaupun memiliki beberapa nilainya yang melebihi batas atas, tidak terlihat seperti sebuah kesalahan atau masih terlihat wajar berdasarkan data apa yang tertera pada kolom tersebut.

# %% [markdown]
# ##Normalization & Standardization

# %%
scaler = preprocessing.StandardScaler()

# %%
standardization_column = ['zn',
                         'indus',
                         'nox',
                         'rm',
                         'age',
                         'dis', 
                         'rad', 
                         'tax',
                         'medv',
                         'ptratio']

for i in standardization_column:
  df[i] = scaler.fit_transform(np.array(df[i]).reshape(-1,1))

# %%
df['b'] = scaler.fit_transform(np.array(df['b']).reshape(-1,1))

# %%
minmax = preprocessing.MinMaxScaler()

# %%
minmax_column = ['crim',
                 'lstat']

for i in minmax_column:
  df[i] = minmax.fit_transform(np.array(df[i]).reshape(-1,1))

# %% [markdown]
# ##Feature Encoding

# %%
df = pd.get_dummies(df, columns = ['chas'])
df
# Out:
#         crim    zn  indus    nox     rm   age     dis  rad  tax  ptratio  \
# 0    0.00632  18.0   2.31  0.538  6.575  65.2  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07  0.469  6.421  78.9  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07  0.469  7.185  61.1  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18  0.458  6.998  45.8  6.0622    3  222     18.7
# 4    0.06905   0.0   2.18  0.458  7.147  54.2  6.0622    3  222     18.7
# ..       ...   ...    ...    ...    ...   ...     ...  ...  ...      ...
# 501  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv  chas_0  chas_1
# 0    396.90   4.98  24.0       1       0
# ...

# %% [markdown]
# hanya kolom 'CHAS' yang mendapatkan perlakuan one hot encoding. Kolom lainnya tidak memerlukan Feature Encoding

# %% [markdown]
# # SAVE DATAFRAME TO CSV

# %%
df.to_csv('Boston-Housing-Clean.csv')
